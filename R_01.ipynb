# %% [markdown]
# # Introducción a R

# %%
set.seed(1)
rnorm(5)
# Out:
# [1] -0.6264538  0.1836433 -0.8356286  1.5952808  0.3295078

# %%
set.seed(1)
runif(n=10, min= 0, max=1)
# Out:
#  [1] 0.26550866 0.37212390 0.57285336 0.90820779 0.20168193 0.89838968
#  [7] 0.94467527 0.66079779 0.62911404 0.06178627

# %%
# Vamos a crear un dataframe en donde tomaremos columnas uniformes.
set.seed(1)
#Hay una funcion integrada en R llamada Matrix
mu <- matrix(runif(n=10, min= 0, max=1), nrow=5)
mu
# Out:
#      [,1]      [,2]
# [1,] 0.2655087 0.89838968
# [2,] 0.3721239 0.94467527
# [3,] 0.5728534 0.66079779
# [4,] 0.9082078 0.62911404
# [5,] 0.2016819 0.06178627

# %%
df <- as.data.frame(mu)
df
# Out:
#   V1        V2
# 1 0.2655087 0.89838968
# 2 0.3721239 0.94467527
# 3 0.5728534 0.66079779
# 4 0.9082078 0.62911404
# 5 0.2016819 0.06178627

# %%
# Vamos a cambiar el nombre de las columnas.
names(df) <- c("A","B")
df
# Out:
#   A         B
# 1 0.2655087 0.89838968
# 2 0.3721239 0.94467527
# 3 0.5728534 0.66079779
# 4 0.9082078 0.62911404
# 5 0.2016819 0.06178627

# %%
Hay dos librerias que son de importancia en R:
- ggplot2 (realiza graficas mas sofisticadas)
- dplyr

# %% [markdown]
# - r Simular muestras
# - p Calcula cdf
# - d Calcula la pdf o pmf
# - q Calcula los cuantiles
#
# Los cuantiles son los numeros reales q tales que
# $$P(X<q)=p $$

# %%
hist(rnorm(1000, mean =1, sd=2))
# Out:
# Plot with title "Histogram of rnorm(1000, mean = 1, sd = 2)"

# %%
?hist
# Out:
# hist                 package:graphics                  R Documentation
#
# s
#
# n:
#
#      The generic function 'hist' computes a histogram of the given data
#      values.  If 'plot = TRUE', the resulting object of class
#      '"histogram"' is plotted by 'plot.histogram', before it is
#      returned.
#
# e:
#
#      hist(x, ...)
#
#      ## Default S3 method:
#      hist(x, breaks = "Sturges",
#           freq = NULL, probability = !freq,
#           include.lowest = TRUE, right = TRUE,
#           density = NULL, angle = 45, col = NULL, border = NULL,
#           main = paste("Histogram of" , xname),
#           xlim = range(breaks), ylim = NULL,
#           xlab = xname, ylab,
#           axes = TRUE, plot = TRUE, labels = FALSE,
#           nclass = NULL, warn.unused = TRUE, ...)
#
# s:
#
#        x: a vector of values for which the histogram is desired.
#
#   breaks: one of:
#
#             â€¢ a vector giving the breakpoints between histogram cells,
#
# ...

# %%
library(ggplot2)

# %%
z = rnorm(100000, mean = 0, sd=1)
ggplot(data = as.data.frame(z), aes(x=z))+geom_histogram(bins = 50, fill = "green", color = "DarkRed")
# Out:
# plot without title

# %%
data <- data.frame(x=rnorm(100), y = rnorm(100))
ggplot(data, aes(x=x, y=y))+geom_point(color="blue")+labs(title ="Scatter Plot", x = "eje-x", y= "eje-y")
# Out:
# plot without title

# %%
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
data <- data.frame(
  name = c("Alice", "Bob", "Charlie"),
  age = c(25, 30, 35),
  score = c(90, 85, 88)
)

# Use dplyr to filter and select data
filtered_data <- data %>%
  filter(age > 25) %>%
  select(name, score)

# Print the filtered data
print(filtered_data)
# Out:
#      name score
# 1     Bob    85
# 2 Charlie    88

# %%
data <- data.frame(
  name = c("Alice", "Bob", "Charlie"),
  age = c(25, 30, 35),
  score = c(90, 85, 88)
)

# %%
data
# Out:
#   name    age score
# 1 Alice   25  90
# 2 Bob     30  85
# 3 Charlie 35  88
